# %% [markdown]
# ![AIcrowd-Logo](https://raw.githubusercontent.com/AIcrowd/AIcrowd/master/app/assets/images/misc/aicrowd-horizontal.png)

# %% [markdown]
# # Getting Started Code for [Chess Win Prediction](https://www.aicrowd.com/challenges/ai-blitz-6/problems/chess-win-prediction) on AIcrowd
# #### Author : Shubhamai

# %% [markdown]
# ## Download Necessary Packages 📚
#
# In this baseline we are going to use FastAI as our main library to train out model and making & submitting predictions

# %%
# !pip install --upgrade fastai git+https://gitlab.aicrowd.com/yoogottamk/aicrowd-cli.git >/dev/null
# %load_ext aicrowd.magic
# Out:
#   Running command git clone -q https://gitlab.aicrowd.com/yoogottamk/aicrowd-cli.git /tmp/pip-req-build-4x1g8p14

# %% [markdown]
# ## Download Data
# The first step is to download out train test data. We will be training a model on the train data and make predictions on test data. We submit our predictions.

# %%
API_KEY = 'b46152c118edae059e08ebd1f8ada78f'  #Please enter your API Key [https://www.aicrowd.com/participants/me]
# %aicrowd login --api-key $API_KEY
# Out:
# Verifying API Key...
# API Key valid
# Saved API Key successfully!

# %%
# %aicrowd dataset download --challenge chess-win-prediction -j 3
# Out:
# HBox(children=(FloatProgress(value=0.0, description='sample_submission.csv', max=118905.0, style=ProgressStyle…
# HBox(children=(FloatProgress(value=0.0, description='test.zip', max=240615696.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='test.csv', max=118904.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='train.csv', max=748910.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='val.csv', max=70910.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='val.zip', max=96410679.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='train.zip', max=964172680.0, style=ProgressStyle(descript…

# %%
# !rm -rf data
# !mkdir data

# !unzip train.zip  -d data/ 
# !unzip val.zip -d data/ 
# !unzip test.zip  -d data/ 

# !mv train.csv data/train.csv
# !mv val.csv data/val.csv
# !mv sample_submission.csv data/sample_submission.csv
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/test/5499.jpg
#   inflating: data/test/55.jpg
#   inflating: data/test/550.jpg
#   inflating: data/test/5500.jpg
#   inflating: data/test/5501.jpg
#   inflating: data/test/5502.jpg
#   inflating: data/test/5503.jpg
#   inflating: data/test/5504.jpg
#   inflating: data/test/5505.jpg
#   inflating: data/test/5506.jpg
#   inflating: data/test/5507.jpg
#   inflating: data/test/5508.jpg
#   inflating: data/test/5509.jpg
#   inflating: data/test/551.jpg
#   inflating: data/test/5510.jpg
#   inflating: data/test/5511.jpg
#   inflating: data/test/5512.jpg
#   inflating: data/test/5513.jpg
#   inflating: data/test/5514.jpg
#   inflating: data/test/5515.jpg
#   inflating: data/test/5516.jpg
#   inflating: data/test/5517.jpg
#   inflating: data/test/5518.jpg
#   inflating: data/test/5519.jpg
#   inflating: data/test/552.jpg
#   inflating: data/test/5520.jpg
#   inflating: data/test/5521.jpg
#   inflating: data/test/5522.jpg
#   inflating: data/test/5523.jpg
#   inflating: data/test/5524.jpg
#   inflating: data/test/5525.jpg
#   inflating: data/test/9977.jpg
#   inflating: data/test/9978.jpg
#   inflating: data/test/9979.jpg
#   inflating: data/test/998.jpg
#   inflating: data/test/9980.jpg
#   inflating: data/test/9981.jpg
#   inflating: data/test/9982.jpg
#   inflating: data/test/9983.jpg
#   inflating: data/test/9984.jpg
#   inflating: data/test/9985.jpg
#   inflating: data/test/9986.jpg
#   inflating: data/test/9987.jpg
#   inflating: data/test/9988.jpg
#   inflating: data/test/9989.jpg
#   inflating: data/test/999.jpg
#   inflating: data/test/9990.jpg
#   inflating: data/test/9991.jpg
#   inflating: data/test/9992.jpg
#   inflating: data/test/9993.jpg
#   inflating: data/test/9994.jpg
#   inflating: data/test/9995.jpg
#   inflating: data/test/9996.jpg
#   inflating: data/test/9997.jpg
#   inflating: data/test/9998.jpg
#   inflating: data/test/9999.jpg

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
from fastai.vision.all import *
import os

# %% [markdown]
# ## Load Data
# - We use pandas 🐼 library to load our data.
# - Pandas loads the data into dataframes and facilitates us to analyse the data.
# - Learn more about it [here](https://www.tutorialspoint.com/python_data_science/python_pandas.htm) 🤓

# %%
train_df = pd.read_csv("data/train.csv")

# %% [markdown]
# ## Visualize the data 👀

# %%
train_df
# Out:
#        ImageID   turn  label
# 0            0  white  white
# 1            1  black  white
# 2            2  white  black
# 3            3  white  white
# 4            4  white  black
# ...        ...    ...    ...
# 39995    39995  black  white
# 39996    39996  white  black
# 39997    39997  white  white
# 39998    39998  black  black
# 39999    39999  black  white
#
# [40000 rows x 3 columns]

# %%
train_df['ImageID'] = train_df['ImageID'].astype(str)+".jpg"
train_df
# Out:
#          ImageID   turn  label
# 0          0.jpg  white  white
# 1          1.jpg  black  white
# 2          2.jpg  white  black
# 3          3.jpg  white  white
# 4          4.jpg  white  black
# ...          ...    ...    ...
# 39995  39995.jpg  black  white
# 39996  39996.jpg  white  black
# 39997  39997.jpg  white  white
# 39998  39998.jpg  black  black
# 39999  39999.jpg  black  white
#
# [40000 rows x 3 columns]

# %%
dls = ImageDataLoaders.from_df(train_df, path="data/train", label_col=2, bs=8)
dls.show_batch()

# %% [markdown]
# # TRAINING PHASE 🏋️

# %%
learn = cnn_learner(dls, resnet152, metrics=F1Score())
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-b121ed2d.pth" to /root/.cache/torch/hub/checkpoints/resnet152-b121ed2d.pth
# HBox(children=(FloatProgress(value=0.0, max=241530880.0), HTML(value='')))

# %% [markdown]
# ## Train the Model

# %%
learn.fine_tune(7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.261634</td>
#       <td>17.677401</td>
#       <td>0.000000</td>
#       <td>17:50</td>
#     </tr>
#   </tbody>
# </table>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       71.43% [5/7 2:03:57<49:35]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130702</td>
#       <td>7.686777</td>
#       <td>0.716200</td>
#       <td>24:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.144957</td>
#       <td>18.107149</td>
#       <td>0.716200</td>
#       <td>24:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.077056</td>
#       <td>2.011621</td>
#       <td>0.713699</td>
#       <td>24:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.059716</td>
#       <td>2.974225</td>
#       <td>0.710943</td>
#       <td>24:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.025000</td>
#       <td>8.414634</td>
#       <td>0.716097</td>
#       <td>24:43</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1177' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       29.43% [1177/4000 06:52<16:30 0.0334]
#     </div>
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882 │
# │ in run_code                                                                  │
# │                                                                              │
# │   2879 │   │   │   try:                                                      │
# │   2880 │   │   │   │   self.hooks.pre_run_code_hook()                        │
# │   2881 │   │   │   │   #rprint('Running code', repr(code_obj)) # dbg         │
# │ ❱ 2882 │   │   │   │   exec(code_obj, self.user_global_ns, self.user_ns)     │
# │   2883 │   │   │   finally:                                                  │
# │   2884 │   │   │   │   # Reset our crash handler in place                    │
# │   2885 │   │   │   │   sys.excepthook = old_excepthook                       │
# │ <ipython-input-11-2580f860cb11>:1 in <module>                                │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/callback/schedule.py:160 in    │
# │ fine_tune                                                                    │
# │                                                                              │
# │   157 │   self.fit_one_cycle(freeze_epochs, slice(base_lr), pct_start=0.99,  │
# │   158 │   base_lr /= 2                                                       │
# │   159 │   self.unfreeze()                                                    │
# │ ❱ 160 │   self.fit_one_cycle(epochs, slice(base_lr/lr_mult, base_lr), pct_st │
# │   161                                                                        │
# │   162 # Cell                                                                 │
# │   163 @docs                                                                  │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/callback/schedule.py:112 in    │
# │ fit_one_cycle                                                                │
# │                                                                              │
# │   109 │   lr_max = np.array([h['lr'] for h in self.opt.hypers])              │
# │   110 │   scheds = {'lr': combined_cos(pct_start, lr_max/div, lr_max, lr_max │
# │   111 │   │   │     'mom': combined_cos(pct_start, *(self.moms if moms is No │
# │ ❱ 112 │   self.fit(n_epoch, cbs=ParamScheduler(scheds)+L(cbs), reset_opt=res │
# │   113                                                                        │
# │   114 # Cell                                                                 │
# │   115 @patch                                                                 │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:211 in fit          │
# │                                                                              │
# │   208 │   │   │   if wd is not None: self.opt.set_hypers(wd=wd)              │
# │   209 │   │   │   self.opt.set_hypers(lr=self.lr if lr is None else lr)      │
# │   210 │   │   │   self.n_epoch = n_epoch                                     │
# │ ❱ 211 │   │   │   self._with_events(self._do_fit, 'fit', CancelFitException, │
# │   212 │                                                                      │
# │   213 │   def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.los │
# │   214 │   def __enter__(self): self(_before_epoch); return self              │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:160 in _with_events │
# │                                                                              │
# │   157 │   │   self.xb,self.yb = b[:i],b[i:]                                  │
# │   158 │                                                                      │
# │   159 │   def _with_events(self, f, event_type, ex, final=noop):             │
# │ ❱ 160 │   │   try: self(f'before_{event_type}');  f()                        │
# │   161 │   │   except ex: self(f'after_cancel_{event_type}')                  │
# │   162 │   │   self(f'after_{event_type}');  final()                          │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:202 in _do_fit      │
# │                                                                              │
# │   199 │   def _do_fit(self):                                                 │
# │   200 │   │   for epoch in range(self.n_epoch):                              │
# │   201 │   │   │   self.epoch=epoch                                           │
# │ ❱ 202 │   │   │   self._with_events(self._do_epoch, 'epoch', CancelEpochExce │
# │   203 │                                                                      │
# │   204 │   def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False │
# │   205 │   │   with self.added_cbs(cbs):                                      │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:160 in _with_events │
# │                                                                              │
# │   157 │   │   self.xb,self.yb = b[:i],b[i:]                                  │
# │   158 │                                                                      │
# │   159 │   def _with_events(self, f, event_type, ex, final=noop):             │
# │ ❱ 160 │   │   try: self(f'before_{event_type}');  f()                        │
# │   161 │   │   except ex: self(f'after_cancel_{event_type}')                  │
# │   162 │   │   self(f'after_{event_type}');  final()                          │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:196 in _do_epoch    │
# │                                                                              │
# │   193 │   │   with torch.no_grad(): self._with_events(self.all_batches, 'val │
# │   194 │                                                                      │
# │   195 │   def _do_epoch(self):                                               │
# │ ❱ 196 │   │   self._do_epoch_train()                                         │
# │   197 │   │   self._do_epoch_validate()                                      │
# │   198 │                                                                      │
# │   199 │   def _do_fit(self):                                                 │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:188 in              │
# │ _do_epoch_train                                                              │
# │                                                                              │
# │   185 │                                                                      │
# │   186 │   def _do_epoch_train(self):                                         │
# │   187 │   │   self.dl = self.dls.train                                       │
# │ ❱ 188 │   │   self._with_events(self.all_batches, 'train', CancelTrainExcept │
# │   189 │                                                                      │
# │   190 │   def _do_epoch_validate(self, ds_idx=1, dl=None):                   │
# │   191 │   │   if dl is None: dl = self.dls[ds_idx]                           │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:160 in _with_events │
# │                                                                              │
# │   157 │   │   self.xb,self.yb = b[:i],b[i:]                                  │
# │   158 │                                                                      │
# │   159 │   def _with_events(self, f, event_type, ex, final=noop):             │
# │ ❱ 160 │   │   try: self(f'before_{event_type}');  f()                        │
# │   161 │   │   except ex: self(f'after_cancel_{event_type}')                  │
# │   162 │   │   self(f'after_{event_type}');  final()                          │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:166 in all_batches  │
# │                                                                              │
# │   163 │                                                                      │
# │   164 │   def all_batches(self):                                             │
# │   165 │   │   self.n_iter = len(self.dl)                                     │
# │ ❱ 166 │   │   for o in enumerate(self.dl): self.one_batch(*o)                │
# │   167 │                                                                      │
# │   168 │   def _do_one_batch(self):                                           │
# │   169 │   │   self.pred = self.model(*self.xb)                               │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:184 in one_batch    │
# │                                                                              │
# │   181 │   def one_batch(self, i, b):                                         │
# │   182 │   │   self.iter = i                                                  │
# │   183 │   │   self._split(b)                                                 │
# │ ❱ 184 │   │   self._with_events(self._do_one_batch, 'batch', CancelBatchExce │
# │   185 │                                                                      │
# │   186 │   def _do_epoch_train(self):                                         │
# │   187 │   │   self.dl = self.dls.train                                       │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:160 in _with_events │
# │                                                                              │
# │   157 │   │   self.xb,self.yb = b[:i],b[i:]                                  │
# │   158 │                                                                      │
# │   159 │   def _with_events(self, f, event_type, ex, final=noop):             │
# │ ❱ 160 │   │   try: self(f'before_{event_type}');  f()                        │
# │   161 │   │   except ex: self(f'after_cancel_{event_type}')                  │
# │   162 │   │   self(f'after_{event_type}');  final()                          │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/learner.py:177 in              │
# │ _do_one_batch                                                                │
# │                                                                              │
# │   174 │   │   self('after_loss')                                             │
# │   175 │   │   if not self.training or not len(self.yb): return               │
# │   176 │   │   self('before_backward')                                        │
# │ ❱ 177 │   │   self.loss_grad.backward()                                      │
# │   178 │   │   self._with_events(self.opt.step, 'step', CancelStepException)  │
# │   179 │   │   self.opt.zero_grad()                                           │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/torch/tensor.py:220 in backward       │
# │                                                                              │
# │    217 │   │   │   │   self,                                                 │
# │    218 │   │   │   │   gradient=gradient,                                    │
# │    219 │   │   │   │   retain_graph=retain_graph,                            │
# │ ❱  220 │   │   │   │   create_graph=create_graph)                            │
# │    221 │   │   torch.autograd.backward(self, gradient, retain_graph, create_ │
# │    222 │                                                                     │
# │    223 │   def register_hook(self, hook):                                    │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/torch/overrides.py:1063 in            │
# │ handle_torch_function                                                        │
# │                                                                              │
# │   1060 │   for overloaded_arg in overloaded_args:                            │
# │   1061 │   │   # Use `public_api` instead of `implementation` so __torch_fun │
# │   1062 │   │   # implementations can do equality/identity comparisons.       │
# │ ❱ 1063 │   │   result = overloaded_arg.__torch_function__(public_api, types, │
# │   1064 │   │                                                                 │
# │   1065 │   │   if result is not NotImplemented:                              │
# │   1066 │   │   │   return result                                             │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/fastai/torch_core.py:329 in           │
# │ __torch_function__                                                           │
# │                                                                              │
# │   326 │   │   if self.debug and func.__name__ not in ('__str__','__repr__'): │
# │   327 │   │   convert=False                                                  │
# │   328 │   │   if _torch_handled(args, self._opt, func): convert,types = type │
# │ ❱ 329 │   │   res = super().__torch_function__(func, types, args=args, kwarg │
# │   330 │   │   if convert: res = convert(res)                                 │
# │   331 │   │   if isinstance(res, TensorBase): res.set_meta(self, as_copy=Tru │
# │   332 │   │   return res                                                     │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/torch/tensor.py:995 in                │
# │ __torch_function__                                                           │
# │                                                                              │
# │    992 │   │   │   return NotImplemented                                     │
# │    993 │   │                                                                 │
# │    994 │   │   with _C.DisableTorchFunction():                               │
# │ ❱  995 │   │   │   ret = func(*args, **kwargs)                               │
# │    996 │   │   │   return _convert(ret, cls)                                 │
# │    997 │                                                                     │
# │    998 │   __module__ = 'torch'                                              │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/torch/tensor.py:221 in backward       │
# │                                                                              │
# │    218 │   │   │   │   gradient=gradient,                                    │
# │    219 │   │   │   │   retain_graph=retain_graph,                            │
# │    220 │   │   │   │   create_graph=create_graph)                            │
# │ ❱  221 │   │   torch.autograd.backward(self, gradient, retain_graph, create_ │
# │    222 │                                                                     │
# │    223 │   def register_hook(self, hook):                                    │
# │    224 │   │   r"""Registers a backward hook.                                │
# │                                                                              │
# │ /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py:132 in     │
# │ backward                                                                     │
# │                                                                              │
# │   129 │                                                                      │
# │   130 │   Variable._execution_engine.run_backward(                           │
# │   131 │   │   tensors, grad_tensors_, retain_graph, create_graph,            │
# │ ❱ 132 │   │   allow_unreachable=True)  # allow_unreachable flag              │
# │   133                                                                        │
# │   134                                                                        │
# │   135 def grad(                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt:

# %% [markdown]
# # Testing Phase 😅
#
# We are almost done. We trained and validated on the training data. Now its the time to predict on test set and make a submission.# Prediction on Evaluation Set

# %% [markdown]
# ## Predict Test Set
# Predict on the test set and you are all set to make the submission!

# %%
test_imgs_name = get_image_files("data/test")
test_dls = dls.test_dl(test_imgs_name)

label_to_class_mapping = {v: k for v, k in enumerate(dls.vocab)}
print(label_to_class_mapping)

test_img_ids = [re.sub(r"\D", "", str(img_name)) for img_name in test_imgs_name]
# Out:
# {0: 'black', 1: 'white'}

# %%
test_dls.show_batch()

# %%
_,_,results = learn.get_preds(dl = test_dls, with_decoded = True)

results = [label_to_class_mapping[i] for i in results.numpy()]
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130702</td>
#       <td>7.686777</td>
#       <td>0.716200</td>
#       <td>24:48</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.144957</td>
#       <td>18.107149</td>
#       <td>0.716200</td>
#       <td>24:52</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.077056</td>
#       <td>2.011621</td>
#       <td>0.713699</td>
#       <td>24:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.059716</td>
#       <td>2.974225</td>
#       <td>0.710943</td>
#       <td>24:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.025000</td>
#       <td>8.414634</td>
#       <td>0.716097</td>
#       <td>24:43</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Save the prediction to csv

# %%
submission = pd.DataFrame({"ImageID":test_img_ids, "label":results})
submission
# Out:
#      ImageID  label
# 0       7255  white
# 1       7113  white
# 2       8581  white
# 3       1383  white
# 4       2914  white
# ...      ...    ...
# 9995    6300  white
# 9996    9115  white
# 9997    4331  white
# 9998    4094  white
# 9999     839  white
#
# [10000 rows x 2 columns]

# %%
submission.to_csv("submission.csv", index=False)

# %% [markdown]
# ## To download the generated csv in colab run the below command

# %%
try:
    from google.colab import files
    files.download('submission.csv') 
except:
    print("Option Only avilable in Google Colab")

# %% [markdown]
# ### Well Done! 👍 We are all set to make a submission and see your name on leaderborad. Let navigate to [challenge page](https://www.aicrowd.com/challenges/ai-blitz-6/problems/chess-win-prediction) and make one.
